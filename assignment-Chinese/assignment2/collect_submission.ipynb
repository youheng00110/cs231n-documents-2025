# %%
from google.colab import drive  # 从google.colab导入drive模块，用于挂载Google Drive

drive.mount('/content/drive')  # 挂载Google Drive到Colab的/content/drive路径下

# 待办：输入作业在你的Drive中的路径
# 例如：'cs231n/assignments/assignment1/'
FOLDERNAME = 'cs231n/assignments/assignment2/'  # 定义作业所在的文件夹路径

assert FOLDERNAME is not None, "[!] 请输入文件夹名称。"  # 断言检查，确保FOLDERNAME已设置，否则抛出提示

import sys  # 导入sys模块，用于操作Python解释器的运行时环境
# 将Google Drive中作业文件夹的路径添加到Python的系统路径中，以便导入该文件夹下的模块
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# %% [markdown]
# # 收集提交内容 - 压缩文件 + 生成PDF
#
# 在你完成所有其他笔记本（`BatchNormalization.ipynb`、`Dropout.ipynb`、`ConvolutionalNetworks.ipynb`、`PyTorch.ipynb`、`RNN_Captioning_pytorch.ipynb`）后，运行此笔记本。
#
# 它将：
#
# * 生成一个包含你的代码（`.py`和`.ipynb`文件）的压缩文件，名为`a2.zip`。
# * 将所有笔记本转换为一个名为`assignment.pdf`的PDF文件。
#
# 如果此步骤的提交准备成功，你将看到以下显示信息：
#
# `### 完成！请将a2.zip和PDF文件提交至Gradescope。 ###`
#
# 请确保将压缩文件和PDF文件下载到你的本地计算机，然后提交至Gradescope。恭喜你成功完成本次作业！

# %%
# %cd /content/drive/My\ Drive/$FOLDERNAME  # 切换到Google Drive中作业文件夹所在的路径
# 安装生成PDF所需的依赖包（texlive相关工具和pandoc），--fix-missing用于修复缺失的依赖
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic texlive-latex-extra pandoc --fix-missing
# !pip install PyPDF2  # 安装PyPDF2库，用于PDF文件处理
# !bash collectSubmission.sh  # 执行收集提交内容的bash脚本，生成压缩文件和PDF
