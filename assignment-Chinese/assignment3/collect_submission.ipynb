# %%
from google.colab import drive  # 从google.colab导入drive模块，用于挂载Google Drive

# 挂载Google Drive到Colab的/content/drive路径下
drive.mount('/content/drive')

# 代办: 输入作业在你的Drive中的路径。
# 例如：'cs231n/assignments/assignment3/'
FOLDERNAME = None  # 此处需要填写作业所在的文件夹路径

# 断言检查，确保FOLDERNAME已被设置，否则抛出错误提示
assert FOLDERNAME is not None, "[!] 请输入文件夹名称。"

# %% [markdown]
# # 收集提交内容 - 压缩文件 + 生成PDF
#
# <font color="red">**注意：** 请在执行此步骤之前运行所有笔记本的所有单元格。我们不会重新评分缺少的单元格输出。</font>
#
# 完成所有其他笔记本后，运行此笔记本。
#
# 它将：
#
# * 生成一个包含你的代码（`.py` 和 `.ipynb`）的 zip 文件，名为 `a3_code_submission.zip`。
# * 将所有笔记本转换为一个名为 `a3_inline_submission.pdf` 的单个PDF文件。
#
# 如果此步骤的提交成功，你应该会看到以下显示消息：
#
# `### 完成！请将 a3_code_submission.zip 和 a3_inline_submission.pdf 提交到 Gradescope。 ###`
#
# 确保将 zip 和 pdf 文件下载到你的本地计算机，然后提交到 Gradescope。恭喜你成功完成了作业！

# %%
# 切换到Google Drive中作业所在的文件夹
# %cd /content/drive/My\ Drive/$FOLDERNAME

# 更新系统包列表
# !sudo apt-get update

# 安装生成PDF所需的依赖包（TeXLive相关工具和pandoc）
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic texlive-latex-extra pandoc --fix-missing

# 安装处理PDF的Python库PyPDF2
# !pip install PyPDF2

# 执行收集提交内容的脚本（生成压缩包和PDF）
# !bash collectSubmission.sh
