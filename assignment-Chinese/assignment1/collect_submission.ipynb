# %%
from google.colab import drive

# 挂载 Google Drive，把云端硬盘映射到 /content/drive
drive.mount('/content/drive')

# TODO: 请填写你的作业在 Drive 中的路径
# 示例：'cs231n/assignments/assignment1/'
# 这里要改成你实际存放 assignment1 的文件夹路径
FOLDERNAME = 'cs231n/assignments/assignment1/'

# 断言：如果 FOLDERNAME 仍然为 None，就报错提示用户必须填写路径
assert FOLDERNAME is not None, "[!] 请填写正确的文件夹路径。"
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 收集提交 – 压缩包 + 生成 PDF
#
# 在完成其他所有 notebook（`knn.ipynb`、`softmax.ipynb`、`two_layer_net.ipynb`、`features.ipynb` 和 `FullyConnectedNets.ipynb`）后，请运行此 notebook。
#
# 它将执行以下操作：
#
# * 将你的代码（`.py` 和 `.ipynb` 文件）打包成一个名为 `a1_code_submission.zip` 的压缩文件。
# * 将所有 notebook 合并并转换成一个名为 `a1_inline_submission.pdf` 的 PDF 文件。
#
# 如果此步骤提交成功，你应该会看到以下提示信息：
#
# `### 完成！请将 a1_code_submission.zip 和 a1_inline_submission.pdf 提交到 Gradescope。###`
#
# 请务必将压缩包和 PDF 文件下载到你的本地电脑，然后上传到 Gradescope。恭喜你成功完成作业！

# %%
# 进入 Google Drive 根目录
# %cd drive/My\ Drive
# 切换到你存放作业的那个文件夹（$FOLDERNAME 是你之前设置的变量）
# %cd $FOLDERNAME

# 安装 LaTeX 及 Pandoc 相关依赖，用于把 notebook 转成 PDF
# --fix-missing 会在缺失包时自动尝试修复
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic texlive-latex-extra pandoc --fix-missing

# 安装 PyPDF2 这个 Python 库，脚本可能用它来合并或检查 PDF
# !pip install PyPDF2

# 运行官方的收集脚本，自动打包代码并生成 PDF
# !bash collectSubmission.sh
